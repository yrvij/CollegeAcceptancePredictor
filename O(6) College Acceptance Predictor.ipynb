# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import random

possibilities = ['accepted','rejected']
X = []
Y = []

for i in range(5000):
    X.append([random.randint(1300,1601),round(random.uniform(3.5,5.0),1),random.randint(1,20)])
    Y.append(random.choice(possibilities))

#Predict for this vector (height, wieghts, shoe size)
P = [[1467, 4.2, 2]]

#{DecisionTreeClassifier}
counter = 0
clf = DecisionTreeClassifier()
clf = clf.fit(X,Y)
print ("1) Using Decision Tree Prediction is " + clf.predict(P)[0])
if clf.predict(P) == 'accepted':
    counter += 1
    
#{KNeighborsClassifier}
knn = KNeighborsClassifier()
knn.fit(X,Y)
print ("2) Using K Neighbors Classifier Prediction is " + knn.predict(P)[0])
if knn.predict(P) == 'accepted':
    counter += 1
    
#{MLPClassifier}
mlpc = MLPClassifier()
mlpc.fit(X,Y)
print ("3) Using MLPC Classifier Prediction is " + mlpc.predict(P)[0])
if mlpc.predict(P) == 'accepted':
    counter += 1

#{RandomForestClassifier}
rfor = RandomForestClassifier()
rfor.fit(X,Y)
print ("4) Using RandomForestClassifier Prediction is " + rfor.predict(P)[0])
if rfor.predict(P) == 'accepted':
    counter += 1
    
#{LogisticRegression}
logr = LogisticRegression()
logr.fit(X,Y)
print("5) Using LogisticRegression Prediction is " + logr.predict(P)[0])
if logr.predict(P) == 'accepted':
    counter += 1

#{NaiveBayesClassifier}
gnb = GaussianNB()
gnb.fit(X,Y)
print("6) Using NaiveBayesClassifier Prediction is " + gnb.predict(P)[0])
if gnb.predict(P) == 'accepted':
    counter += 1

print()
for item in X:
    print(item)
print(P)
print()
print('You have approximately a ' + str(round(((counter/6)*100),2)) + '% chance of acceptance.')
# Out:
# 1) Using Decision Tree Prediction is rejected
# 2) Using K Neighbors Classifier Prediction is rejected
# 3) Using MLPC Classifier Prediction is rejected
# 4) Using RandomForestClassifier Prediction is rejected
# 5) Using LogisticRegression Prediction is rejected
# 6) Using NaiveBayesClassifier Prediction is accepted
#
# [1426, 4.7, 5]
# [1411, 3.6, 5]
# [1381, 4.5, 8]
# [1444, 4.4, 17]
# [1432, 4.5, 6]
# [1480, 4.3, 20]
# [1351, 4.4, 1]
# [1548, 4.9, 14]
# [1587, 3.8, 3]
# [1457, 3.8, 1]
# [1361, 4.5, 13]
# [1543, 3.7, 16]
# [1364, 4.8, 6]
# [1567, 4.0, 8]
# [1505, 4.4, 6]
# [1381, 4.6, 16]
# [1484, 4.6, 7]
# [1477, 4.4, 9]
# [1414, 4.7, 7]
# [1312, 3.7, 2]
# [1380, 4.3, 10]
# [1355, 4.4, 13]
# [1427, 4.7, 17]
# [1517, 3.8, 15]
# [1368, 3.9, 8]
# [1549, 4.1, 3]
# [1433, 4.8, 10]
# [1372, 3.9, 1]
# [1509, 4.4, 19]
# [1396, 3.8, 14]
# [1495, 4.1, 17]
# [1583, 3.5, 5]
# [1383, 4.5, 3]
# [1390, 4.9, 13]
# [1428, 4.7, 18]
# [1432, 4.9, 20]
# [1441, 4.0, 2]
# [1454, 4.4, 11]
# ...
